# %%
df1=spark.read.csv("/Workspace/Users/aravind4718@gmail.com/aravind_repo/sap-data-pipeline/bronze/consolidated_customers.csv",header=True,inferSchema=True)

display(df1.head(5))

# %%
df2=spark.read.csv("/Workspace/Users/aravind4718@gmail.com/aravind_repo/sap-data-pipeline/bronze/orders_bureau_transactional_system.csv",header=True,inferSchema=True)

display(df2.head(5))

# %%
df3=spark.read.csv("/Workspace/Users/aravind4718@gmail.com/aravind_repo/sap-data-pipeline/bronze/orders_office_goods.csv",header=True,inferSchema=True)

display(df3.head(5))

# %%
from pyspark.sql.functions import *
df1.filter(col("officegoods_customer_id").isNull()).count()
